# %% [markdown]
# ## Regressão por árvore de decisão

# %%
# Decision Tree Regression

# Importing the dataset
dataset = read.csv('Position_Salaries.csv')
dataset = dataset[2:3]

# %%
dataset
# Out:
#    Level Salary
# 1   1      45000
# 2   2      50000
# 3   3      60000
# 4   4      80000
# 5   5     110000
# 6   6     150000
# 7   7     200000
# 8   8     300000
# 9   9     500000
# 10 10    1000000

# %%
# Fitting Decision Tree Regression to the dataset
install.packages('rpart')
# Out:
# The downloaded binary packages are in
# 	/var/folders/qq/gkyyxk3d0q769zkwc0hf1mfw0000gn/T//RtmpUqW3qz/downloaded_packages

# %%
library(rpart)

# %%
regressor = rpart(formula = Salary ~ ., data = dataset, control = rpart.control(minsplit = 1))

# %%
regressor
# Out:
# n= 10
#
# node), split, n, deviance, yval
#       * denotes terminal node
#
# 1) root 10 806622500000  249500
#   2) Level< 8.5 8  55371880000  124375
#     4) Level< 6.5 6   8287500000   82500 *
#     5) Level>=6.5 2   5000000000  250000 *
#   3) Level>=8.5 2 125000000000  750000
#     6) Level< 9.5 1            0  500000 *
#     7) Level>=9.5 1            0 1000000 *

# %%
y_pred = predict(regressor, data.frame(Level = 6.5))
y_pred
# Out:
#      1
# 250000

# %%
# Visualising the Decision Tree Regression results (higher resolution)
# install.packages('ggplot2')
library(ggplot2)
x_grid = seq(min(dataset$Level), max(dataset$Level), 0.01)
ggplot() +
  geom_point(aes(x = dataset$Level, y = dataset$Salary),
             colour = 'red') +
  geom_line(aes(x = x_grid, y = predict(regressor, newdata = data.frame(Level = x_grid))),
            colour = 'blue') +
  ggtitle('Truth or Bluff (Decision Tree Regression)') +
  xlab('Level') +
  ylab('Salary')
# Out:
# plot without title

# %% [markdown]
# Mais eficiente quando há mais dimensões de dados.
