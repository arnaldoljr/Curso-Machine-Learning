# %% [markdown]
# ## Random Forest Regression

# %%
# Random Forest Regression

# Importing the dataset
dataset = read.csv('Position_Salaries.csv')
dataset = dataset[2:3]

# %%
dataset
# Out:
#    Level Salary
# 1   1      45000
# 2   2      50000
# 3   3      60000
# 4   4      80000
# 5   5     110000
# 6   6     150000
# 7   7     200000
# 8   8     300000
# 9   9     500000
# 10 10    1000000

# %%
# Fitting Random Forest Regression to the dataset
install.packages('randomForest')
# Out:
# The downloaded binary packages are in
# 	/var/folders/qq/gkyyxk3d0q769zkwc0hf1mfw0000gn/T//Rtmph6p9zu/downloaded_packages

# %%
library(randomForest)
# Out:
# Warning message:
# “package ‘randomForest’ was built under R version 3.4.4”randomForest 4.6-14
# Type rfNews() to see new features/changes/bug fixes.

# %%
set.seed(1234)
regressor = randomForest(x = dataset[1],#ASSIM EU PEGO EUMM DATAFRAME
                         y = dataset$Salary,#ASSIM EU PEGO UM VETOR
                         ntree = 10)

# %%
regressor
# Out:
# Call:
#  randomForest(x = dataset[1], y = dataset$Salary, ntree = 10)
#                Type of random forest: regression
#                      Number of trees: 10
# No. of variables tried at each split: 1
#
#           Mean of squared residuals: 47078889448
#                     % Var explained: 41.63

# %%
# Visualising the Random Forest Regression results (higher resolution)
# install.packages('ggplot2')
library(ggplot2)
x_grid = seq(min(dataset$Level), max(dataset$Level), 0.01)
ggplot() +
  geom_point(aes(x = dataset$Level, y = dataset$Salary),
             colour = 'red') +
  geom_line(aes(x = x_grid, y = predict(regressor, newdata = data.frame(Level = x_grid))),
            colour = 'blue') +
  ggtitle('Truth or Bluff (Random Forest Regression)') +
  xlab('Level') +
  ylab('Salary')
# Out:
# Attaching package: ‘ggplot2’
#
# The following object is masked from ‘package:randomForest’:
#
#     margin
# plot without title

# %% [raw]
# Quanto mais arvores usadas...mais splits eu terei....contudo nem sempre isso melhora a acurácia do método.

# %%
y_pred = predict(regressor, data.frame(Level = 6.5))
y_pred
# Out:
#      1
# 145900

# %%
#agora com 100 arvores
set.seed(1234)
regressor = randomForest(x = dataset[1],#ASSIM EU PEGO EUMM DATAFRAME
                         y = dataset$Salary,#ASSIM EU PEGO UM VETOR
                         ntree = 100)

# %%
#praticamente nada muda..
# Visualising the Random Forest Regression results (higher resolution)
# install.packages('ggplot2')
library(ggplot2)
x_grid = seq(min(dataset$Level), max(dataset$Level), 0.01)
ggplot() +
  geom_point(aes(x = dataset$Level, y = dataset$Salary),
             colour = 'red') +
  geom_line(aes(x = x_grid, y = predict(regressor, newdata = data.frame(Level = x_grid))),
            colour = 'blue') +
  ggtitle('Truth or Bluff (Random Forest Regression)') +
  xlab('Level') +
  ylab('Salary')
# Out:
# plot without title

# %%
y_pred = predict(regressor, data.frame(Level = 6.5))
y_pred
# Out:
#        1
# 159386.7

# %%
#agora com 500 arvores
set.seed(1234)
regressor = randomForest(x = dataset[1],#ASSIM EU PEGO EUMM DATAFRAME
                         y = dataset$Salary,#ASSIM EU PEGO UM VETOR
                         ntree = 500)

# %%
#praticamente nada muda..
# Visualising the Random Forest Regression results (higher resolution)
# install.packages('ggplot2')
library(ggplot2)
x_grid = seq(min(dataset$Level), max(dataset$Level), 0.01)
ggplot() +
  geom_point(aes(x = dataset$Level, y = dataset$Salary),
             colour = 'red') +
  geom_line(aes(x = x_grid, y = predict(regressor, newdata = data.frame(Level = x_grid))),
            colour = 'blue') +
  ggtitle('Truth or Bluff (Random Forest Regression)') +
  xlab('Level') +
  ylab('Salary')
# Out:
# plot without title

# %%
#melhore resultado
y_pred = predict(regressor, data.frame(Level = 6.5))
y_pred
# Out:
#        1
# 160907.7

# %%
dataset
# Out:
#    Level Salary
# 1   1      45000
# 2   2      50000
# 3   3      60000
# 4   4      80000
# 5   5     110000
# 6   6     150000
# 7   7     200000
# 8   8     300000
# 9   9     500000
# 10 10    1000000
